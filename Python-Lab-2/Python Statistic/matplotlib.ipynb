# %%
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import csv

df=pd.read_csv("Train.csv")
print(df)
file.close()

plt.hist(df['ApplicantIncome'], bins = 50)
plt.show()

sns.boxplot( x=df["Education"], y=df["ApplicantIncome"] )
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
fig = plt.figure()

fig, axs = plt.subplots(2)

#Applicants=[(df[df['Credit_History']==0].count()) , (df[df['Credit_History']==1].count())]
#print(Applicants)

axs[0].plot(df['Credit_History'], )

df_Loan_stat = pd.get_dummies(df['Loan_Status'])
df_new = pd.concat([df, df_Loan_stat], axis=1)
print(df_new)

axs[1].plot(df_new['Credit_History'], df_new['Loan_Status'])
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
